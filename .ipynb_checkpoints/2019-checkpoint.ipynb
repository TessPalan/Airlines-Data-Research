# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import pathlib

# %%
flights_1 = pd.read_csv('data/flight_destinations/flights_2019_1.csv')

# %%
flights_1_cleaned = flights_1.drop(columns='Unnamed: 9')

# %%
flights_1_cleaned
# Out:
#          YEAR  QUARTER ORIGIN ORIGIN_COUNTRY ORIGIN_STATE_ABR DEST  \
# 0        2019        1    LAX             US               CA  OGG
# 1        2019        1    SEA             US               WA  TPA
# 2        2019        1    MSP             US               MN  SAN
# 3        2019        1    SEA             US               WA  ATL
# 4        2019        1    MSP             US               MN  BDL
# ...       ...      ...    ...            ...              ...  ...
# 9846811  2019        1    SLC             US               UT  DEN
# 9846812  2019        1    AUS             US               TX  SAT
# 9846813  2019        1    DEN             US               CO  ORD
# 9846814  2019        1    MCO             US               FL  AUS
# 9846815  2019        1    MCO             US               FL  DEN
#
#         DEST_COUNTRY DEST_STATE_ABR OPERATING_CARRIER
# 0                 US             HI                AS
# ...

# %%
flights_2 = pd.read_csv('data/flight_destinations/flights_2019_2.csv') 
flights_2_cleaned = flights_2.drop(columns='Unnamed: 9')
flights_2_cleaned
# Out:
#           YEAR  QUARTER ORIGIN ORIGIN_COUNTRY ORIGIN_STATE_ABR DEST  \
# 0         2019        2    LAX             US               CA  PHX
# 1         2019        2    DEN             US               CO  SLC
# 2         2019        2    DEN             US               CO  SLC
# 3         2019        2    DEN             US               CO  SLC
# 4         2019        2    PHX             US               AZ  SNA
# ...        ...      ...    ...            ...              ...  ...
# 11355392  2019        2    BWI             US               MD  OKC
# 11355393  2019        2    BWI             US               MD  ORF
# 11355394  2019        2    BWI             US               MD  PBI
# 11355395  2019        2    BWI             US               MD  PHX
# 11355396  2019        2    BWI             US               MD  PVD
#
#          DEST_COUNTRY DEST_STATE_ABR OPERATING_CARRIER
# 0                  US             AZ                OO
# ...

# %%
flights_3 = pd.read_csv('data/flight_destinations/flights_2019_3.csv') 
flights_3_cleaned = flights_3.drop(columns='Unnamed: 9')
flights_3_cleaned
# Out:
#           YEAR  QUARTER ORIGIN ORIGIN_COUNTRY ORIGIN_STATE_ABR DEST  \
# 0         2019        3    MSP             US               MN  DLH
# 1         2019        3    ORD             US               IL  SBN
# 2         2019        3    SEA             US               WA  SBP
# 3         2019        3    IAH             US               TX  ECP
# 4         2019        3    LAX             US               CA  JFK
# ...        ...      ...    ...            ...              ...  ...
# 10949352  2019        3    ATL             US               GA  BUF
# 10949353  2019        3    ATL             US               GA  BUF
# 10949354  2019        3    ATL             US               GA  DEN
# 10949355  2019        3    ATL             US               GA  DFW
# 10949356  2019        3    ATL             US               GA  FLL
#
#          DEST_COUNTRY DEST_STATE_ABR OPERATING_CARRIER
# 0                  US             MN                OO
# ...

# %%
flights_4 = pd.read_csv('data/flight_destinations/flights_2019_4.csv') 
flights_4_cleaned = flights_4.drop(columns='Unnamed: 9')
flights_4_cleaned
# Out:
#           YEAR  QUARTER ORIGIN ORIGIN_COUNTRY ORIGIN_STATE_ABR DEST  \
# 0         2019        4    DTW             US               MI  LAN
# 1         2019        4    SLC             US               UT  SGU
# 2         2019        4    SFO             US               CA  EUG
# 3         2019        4    IAH             US               TX  EWR
# 4         2019        4    IAH             US               TX  MFE
# ...        ...      ...    ...            ...              ...  ...
# 11108278  2019        4    DFW             US               TX  DCA
# 11108279  2019        4    ORD             US               IL  LAX
# 11108280  2019        4    ORD             US               IL  XNA
# 11108281  2019        4    DFW             US               TX  SBA
# 11108282  2019        4    ORD             US               IL  SGF
#
#          DEST_COUNTRY DEST_STATE_ABR OPERATING_CARRIER
# 0                  US             MI                OO
# ...

# %%
flights_2019 = pd.concat([flights_1, flights_2, flights_3, flights_4], ignore_index=True).drop(columns='Unnamed: 9')
flights_2019
# Out:
#           YEAR  QUARTER ORIGIN ORIGIN_COUNTRY ORIGIN_STATE_ABR DEST  \
# 0         2019        1    LAX             US               CA  OGG
# 1         2019        1    SEA             US               WA  TPA
# 2         2019        1    MSP             US               MN  SAN
# 3         2019        1    SEA             US               WA  ATL
# 4         2019        1    MSP             US               MN  BDL
# ...        ...      ...    ...            ...              ...  ...
# 43259848  2019        4    DFW             US               TX  DCA
# 43259849  2019        4    ORD             US               IL  LAX
# 43259850  2019        4    ORD             US               IL  XNA
# 43259851  2019        4    DFW             US               TX  SBA
# 43259852  2019        4    ORD             US               IL  SGF
#
#          DEST_COUNTRY DEST_STATE_ABR OPERATING_CARRIER
# 0                  US             HI                AS
# ...

# %%
flights_2019_renamed = flights_2019.rename(columns={
        "YEAR": "Year", 
        "QUARTER": "Quarter", 
        "ORIGIN": "Origin_Airtport", 
        "ORIGIN_COUNTRY": "Origin_Country", 
        "ORIGIN_STATE_ABR": "Origin_State",
        "DEST": "Destination_Airport", 
        "DEST_COUNTRY": "Destination_Country", 
        "DEST_STATE_ABR": "Destination_State",
        "OPERATING_CARRIER": "Airline_Code"
})
flights_2019_renamed
# Out:
#           Year  Quarter Origin_Airtport Origin_Country Origin_State  \
# 0         2019        1             LAX             US           CA
# 1         2019        1             SEA             US           WA
# 2         2019        1             MSP             US           MN
# 3         2019        1             SEA             US           WA
# 4         2019        1             MSP             US           MN
# ...        ...      ...             ...            ...          ...
# 43259848  2019        4             DFW             US           TX
# 43259849  2019        4             ORD             US           IL
# 43259850  2019        4             ORD             US           IL
# 43259851  2019        4             DFW             US           TX
# 43259852  2019        4             ORD             US           IL
#
#          Destination_Airport Destination_Country Destination_State  \
# 0                        OGG                  US                HI
# ...

# %%
 flights_2019_indexed = flights_2019_renamed.set_index('Year')

# %%
flights_2019_indexed.to_csv('data/flights_2019.csv')
